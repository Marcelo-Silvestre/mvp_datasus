-- %% [markdown]
-- #1- Copiar as tabelas delta da camada bronze para a silver.

-- %%
%python
# Lista as tabelas do schema bronze
tabelas = spark.sql("SHOW TABLES IN mvp_datasus.bronze").collect()

for t in tabelas:
    nome = t["tableName"]

    print(f"\n=== Copiando tabela: {nome} ===")

    spark.sql(f"""
        CREATE TABLE IF NOT EXISTS mvp_datasus.silver.`{nome}`
        DEEP CLONE mvp_datasus.bronze.`{nome}`;
    """)

print("\nFinalizado.")
-- Out:
-- === Copiando tabela: obitos_geral ===
--
-- === Copiando tabela: obitos_hiv_faixa_0_10 ===
--
-- === Copiando tabela: obitos_hiv_faixa_0_10_fem ===
--
-- === Copiando tabela: obitos_hiv_faixa_0_10_masc ===
--
-- === Copiando tabela: obitos_hiv_faixa_10_25 ===
--
-- === Copiando tabela: obitos_hiv_faixa_10_25_fem ===
--
-- === Copiando tabela: obitos_hiv_faixa_10_25_masc ===
--
-- === Copiando tabela: obitos_hiv_faixa_25_40 ===
--
-- === Copiando tabela: obitos_hiv_faixa_25_40_fem ===
--
-- === Copiando tabela: obitos_hiv_faixa_25_40_masc ===
--
-- === Copiando tabela: obitos_hiv_faixa_40_55 ===
--
-- === Copiando tabela: obitos_hiv_faixa_40_55_fem ===
--
-- === Copiando tabela: obitos_hiv_faixa_40_55_masc ===
--
-- === Copiando tabela: obitos_hiv_faixa_55_65 ===
--
-- === Copiando tabela: obitos_hiv_faixa_55_65_fem ===
--
-- === Copiando tabela: obitos_hiv_faixa_55_65_masc ===
--
-- === Copiando tabela: obitos_hiv_faixa_65_mais ===
--
-- === Copiando tabela: obitos_hiv_faixa_65_mais_fem ===
--
-- === Copiando tabela: obitos_hiv_faixa_65_mais_masc ===
--
-- === Copiando tabela: obitos_hiv_fem ===
--
-- === Copiando tabela: obitos_hiv_geral ===
--
-- === Copiando tabela: obitos_hiv_masc ===
--
-- Finalizado.
